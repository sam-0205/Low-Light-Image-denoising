# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = tf.saved_model.load('f_model/')

# %%
import numpy as np

# %%
def predict_l(original_image):
    image = keras.preprocessing.image.img_to_array(original_image)
    image = image.astype("float32") / 255.0
    image = np.expand_dims(image, axis=0)
    output_image = model(image)
    output_image = tf.cast((output_image[0, :, :, :] * 255), dtype=np.uint8)
    output_image = Image.fromarray(output_image.numpy())
    return output_image

# %%
from PIL import Image
import cv2

# %%
img = Image.open('C:\\Users\\Sameer Rath\Desktop\\django\\imageweb\\uploads\\478.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 img = Image.open('C:\\Users\\Sameer Rath\Desktop\\django\\imageweb\\uploads\\478.png')
#
# File c:\Users\Sameer Rath\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:3218, in open(fp, mode, formats)
#    3215     filename = fp
#    3217 if filename:
# -> 3218     fp = builtins.open(filename, "rb")
#    3219     exclusive_fp = True
#    3221 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Sameer Rath\\Desktop\\django\\imageweb\\uploads\\478.png'

# %%
img = img.resize((256,256))

# %%
out = predict_l(img)

# %%
# out= out.resize(sz)
print(type(out))
# Out:
# <class 'PIL.Image.Image'>

# %%
out
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
out = np.array(out)

# %%
out
# Out:
# array([[[219, 218, 231],
#         [216, 218, 233],
#         [218, 222, 235],
#         ...,
#         [209, 208, 227],
#         [201, 205, 224],
#         [204, 202, 224]],
#
#        [[219, 217, 231],
#         [219, 218, 233],
#         [219, 220, 233],
#         ...,
#         [209, 208, 226],
#         [206, 205, 226],
#         [206, 202, 226]],
#
#        [[218, 220, 233],
#         [219, 220, 234],
#         [219, 222, 234],
#         ...,
#         [206, 205, 226],
#         [206, 205, 226],
#         [201, 208, 226]],
#
#        ...,
#
#        [[  0,  24,   0],
#         [  0,  24,   0],
#         [  0,  24,   0],
#         ...,
#         [ 65,  96,  98],
#         [ 82,  96, 114],
#         [ 65,  81,  79]],
#
#        [[  0,  24,   0],
#         [  0,  24,   0],
#         [  0,  24,   0],
#         ...,
#         [ 82,  81,  98],
#         [ 82,  81,  79],
#         [ 82,  64, 114]],
#
#        [[  0,  24,   0],
#         [  0,  24,   0],
#         [  0,  24,   0],
#         ...,
#         [ 82,  81, 114],
#         [ 97,  81, 114],
#         [ 65,  96, 114]]], dtype=uint8)
